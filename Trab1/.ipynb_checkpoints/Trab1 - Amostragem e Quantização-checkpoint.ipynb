# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# %%
img = mpimg.imread('lenna.jpg') # read image from file to array
# fig = plt.figure(figsize=(5,5))
imgplot = plt.imshow(img, cmap='gray')
# plt.show()

# %% [markdown]
# Ravel transforma a matriz em vetor

# %%
hist = cv2.calcHist([img],[0],None,[256], [0,256] )
plt.hist(img.ravel(), 256,[0,256]);

plt.title('Histograma da Figura')
plt.show()

# %%
img2 = img[::2,::2] # mostra 1 em cada 2 pixels (subamostragem)
imgplot = plt.imshow(img2, cmap='gray')

# %%
img2[:,:]
# Out:
# array([[135, 132, 127, ...,  93, 100,  84],
#        [128, 128, 136, ...,  91, 103,  53],
#        [125, 135, 152, ...,  99,  52,  26],
#        ...,
#        [ 17, 161,  50, ...,  50,  80,  79],
#        [ 57, 157,  68, ...,  56,  52,  75],
#        [ 25, 124,  74, ...,  55,  88,  49]], dtype=uint8)

# %%
px = img[1:30,1]
print ('saida 1: ' , px)

px = img2[1:30,1]
print ('saida 2: ', px)
# Out:
# saida 1:  [137 138 137 136 135 134 133 130 130 131 131 131 131 131 132 129 129 130
#  130 130 130 130 130 132 129 127 129 131 130]
# saida 2:  [138 136 132 133 132 131 131 129 131 132 129 130 127 132 130 133 135 132
#  134 139 134 135 136 138 136 133 133 131 137]
